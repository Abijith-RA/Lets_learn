# %% [raw]
# PANDAS FUNDAMENTALS

# %%
import pandas as pd

# %%
#explicit indexing
temperatures=pd.Series([32,24,35], index=["Mon", "Tue", "Wed"], dtype='int16')
print(temperatures)
# Out:
# Mon    32
# Tue    24
# Wed    35
# dtype: int16

# %%
print(temperatures+2)
# Out:
# Mon    34
# Tue    26
# Wed    37
# dtype: int16

# %%
#Default o,1,2
s=pd.Series([10,20,30])
print(s+2)
# Out:
# 0    12
# 1    22
# 2    32
# dtype: int64

# %%
print(temperatures["Tue"])
# Out:
# 24

# %% [raw]
# DATA FRAMES : COLLECTION OF SERIES

# %%
data={'Name':["Alice", "Ann", "Alan"], 'Age': [23,18,30]}
students=pd.DataFrame(data)
print(students)
# Out:
#     Name  Age
# 0  Alice   23
# 1    Ann   18
# 2   Alan   30
# 0    Alice
# 1      Ann
# 2     Alan
# Name: Name, dtype: str

# %%
print(students['Age'])
# Out:
# 0    23
# 1    18
# 2    30
# Name: Age, dtype: int64

# %%
# first 5 rows
df=pd.read_csv(r'C:\ML-Learning\module3_venv\CSV_FILES\data.csv')
print(df.head())
# Out:
#    StudentID    Name  Age  Score
# 0          1    Neha   21     85
# 1          2    Ravi   22     90
# 2          3     Sam   23     78
# 3          4    Alan   20     97
# 4          5  Aleena   20     79

# %%
# last 5 rows
print(df.tail())
# Out:
#    StudentID    Name  Age  Score
# 1          2    Ravi   22     90
# 2          3     Sam   23     78
# 3          4    Alan   20     97
# 4          5  Aleena   20     79
# 5          6   Pavan   21     89

# %%
# full csv
print(df.info)
# Out:
# <bound method DataFrame.info of    StudentID    Name  Age  Score
# 0          1    Neha   21     85
# 1          2    Ravi   22     90
# 2          3     Sam   23     78
# 3          4    Alan   20     97
# 4          5  Aleena   20     79
# 5          6   Pavan   21     89>

# %%
# data types of columns
print(df.columns)
# Out:
# Index(['StudentID', 'Name', 'Age', 'Score'], dtype='str')

# %%
print(df.dtypes)
# Out:
# StudentID    int64
# Name           str
# Age          int64
# Score        int64
# dtype: object

# %%
print(df.describe())
# Out:
#        StudentID        Age      Score
# count   6.000000   6.000000   6.000000
# mean    3.500000  21.166667  86.333333
# std     1.870829   1.169045   7.201852
# min     1.000000  20.000000  78.000000
# 25%     2.250000  20.250000  80.500000
# 50%     3.500000  21.000000  87.000000
# 75%     4.750000  21.750000  89.750000
# max     6.000000  23.000000  97.000000

# %%
# array of distinct values
print(df['Age'].unique())
# Out:
# [21 22 23 20]

# %%
# count of distinct values
print(df['Age'].nunique())
# Out:
# 4

# %%
# frequency of each value
print(df['Age'].value_counts())
# Out:
# Age
# 21    2
# 20    2
# 22    1
# 23    1
# Name: count, dtype: int64

# %%
# missing values per column
print(df.isnull().sum())
# Out:
# StudentID    0
# Name         0
# Age          0
# Score        0
# dtype: int64
