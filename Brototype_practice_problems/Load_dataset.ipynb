# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('module3_venv/CSV_FILES/students.csv')

# %%
print(df.shape)
# Out:
# (5, 5)

# %%
print(df.head())
# Out:
#    StudentID   Name  Age  Score       City
# 0          1   Neha   21     85      Kochi
# 1          2   Ravi   22     90    Chennai
# 2          3    Sam   23     78  Bangalore
# 3          4    Anu   22     88      Kochi
# 4          5  Kiran   24     65    Chennai

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   StudentID  5 non-null      int64
#  1   Name       5 non-null      str
#  2   Age        5 non-null      int64
#  3   Score      5 non-null      int64
#  4   City       5 non-null      str
# dtypes: int64(3), str(2)
# memory usage: 332.0 bytes
# None

# %%
print(df.columns)
# Out:
# Index(['StudentID', 'Name', 'Age', 'Score', 'City'], dtype='str')

# %%
print(df.dtypes)
# Out:
# StudentID    int64
# Name           str
# Age          int64
# Score        int64
# City           str
# dtype: object

# %%
print(df.tail())
# Out:
#    StudentID   Name  Age  Score       City
# 0          1   Neha   21     85      Kochi
# 1          2   Ravi   22     90    Chennai
# 2          3    Sam   23     78  Bangalore
# 3          4    Anu   22     88      Kochi
# 4          5  Kiran   24     65    Chennai

# %%
# Statistics
print(df.describe())
# Out:
#        StudentID        Age      Score
# count   5.000000   5.000000   5.000000
# mean    3.000000  22.400000  81.200000
# std     1.581139   1.140175  10.134101
# min     1.000000  21.000000  65.000000
# 25%     2.000000  22.000000  78.000000
# 50%     3.000000  22.000000  85.000000
# 75%     4.000000  23.000000  88.000000
# max     5.000000  24.000000  90.000000

# %%
print(df['Age'].unique)
# Out:
# <bound method Series.unique of 0    21
# 1    22
# 2    23
# 3    22
# 4    24
# Name: Age, dtype: int64>

# %%
print(df['Age'].nunique())
# Out:
# 4

# %%
print(df['Age'].value_counts())
# Out:
# Age
# 22    2
# 21    1
# 23    1
# 24    1
# Name: count, dtype: int64

# %%
print(df.isnull().sum())
# Out:
# StudentID    0
# Name         0
# Age          0
# Score        1
# City         1
# dtype: int64

# %% [raw]
# FILTERING DATA

# %%
print(df[(df['City']!='Kochi')& (df['Age']>=23)])
# Out:
#    StudentID   Name  Age  Score       City
# 2          3    Sam   23   78.0  Bangalore
# 4          5  Kiran   24   65.0        NaN

# %%
print(df.sort_values('Age'))
# Out:
#    StudentID   Name  Age  Score       City
# 0          1   Neha   21   85.0      Kochi
# 1          2   Ravi   22    NaN    Chennai
# 3          4    Anu   22   88.0      Kochi
# 2          3    Sam   23   78.0  Bangalore
# 4          5  Kiran   24   65.0        NaN

# %%
print(df.sort_values(['City', 'Score'], ascending=[True, False]))
# Out:
#    StudentID   Name  Age  Score       City
# 2          3    Sam   23   78.0  Bangalore
# 1          2   Ravi   22    NaN    Chennai
# 3          4    Anu   22   88.0      Kochi
# 0          1   Neha   21   85.0      Kochi
# 4          5  Kiran   24   65.0        NaN
